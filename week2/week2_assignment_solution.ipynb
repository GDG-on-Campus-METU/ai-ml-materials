# %% [markdown]
# <a href="https://colab.research.google.com/github/GDG-on-Campus-METU/ai-ml-materials/blob/main/week2/week2_assignment_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
#
# # 00. About Assignment
#
#
# ---

# %% [markdown]
# **There are 5 questions in this assignment**
#
#
# **To complete this assignment:**
#
# 1.   Run the code block below to import libraries
# 1.   Replace **all** `#TODO` comments with your answers.
# 2.   Run **all** code blocks under "01. Assignment" section.
# 3.   Run the code block under "02. Complete the Assignment" section.
# 4.   Confirm that you completed this assignment without cheating by typing `"I confirm"`
# 4.   A csv file named `w2_submission.csv ` will appear on files (you can reach files on the bar on the left) after you run the block.
# 5. Download `w2_submission.csv`.
# 5.   Send the file to your instructors via Google Classroom.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %% [markdown]
# ---
#
#
# # 01. Assignment
#
#
# ---

# %% [markdown]
# ## Q0 - Personal Info

# %%
from datetime import datetime

now = datetime.now()
datetimenow = now.strftime("%d/%m/%Y %H:%M:%S")
name = input("Enter your full name:  ")
# Out:
# Enter your full name:  Efe Kaan Güler

# %% [markdown]
# ## Q1 - NumPy Arrays

# %% [markdown]
# 1.   Create a numpy array from `arr_list` and assign it to variable `arr`.
# 2.   Create a numpy array consists of ones and assign it to variable `ones`. Shape of the array must be `(3,3)`.
# 3.   Create a numpy array consists of intagers from `0` to `9` (including `0`, not including `9`) and assign it to variable `int_arr`.
# 4.   Change the shape of `int_arr` to `(3,3)`.
# 5.   Assign first element of `arr` to variable `first_element`.
# 6.   Assign element wise multiplication of `arr` and `int_arr` to variable `ewmul_arr`.
# 7.   Assign matrix multiplication of `arr` and `int_arr` to variable `mmul_arr`.

# %%
arr_list = [[1,2,3],[4,5,6],[7,8,9]]

#1. Creating an array from a list
arr = np.array(arr_list)

#2. Creating an array consists of ones
ones = np.ones((3,3))

#3. Creating an array consists of integers from 0 to 10
int_arr = np.arange(9)

#4. Changing the shape of an array
int_arr = int_arr.reshape((3,3))

#5. First element of an array
first_element = arr[0,0]

#6. Element-wise multiplication of two arrays
ewmul_arr = arr * int_arr

#7. Matrix multiplication of two arrays
mmul_arr = arr @ int_arr

# %%
# THIS BLOCK IS FOR GRADING
# DO NOT MODIFY THIS BLOCK

q1_answer = [str(arr), str(ones), str(int_arr), str(first_element), str(ewmul_arr), str(mmul_arr)]

# %% [markdown]
# ## Q2 - Pandas DataFremes

# %% [markdown]
# 1.   Create a pandas dataframe from `df_dict` and assign it to variable `df`.
# 2.   Fill missing value with `10` and assign it to variable `filled_df`.
# 3.   Fill missing values using interpolation and assign it to variable `in_filled_df`.
# 4.   Convert `in_filled_df` to a numpy array and assign it to variable `np_array`.

# %%
df_dict = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, np.nan, 35],
        'City': ['New York', 'San Francisco', 'Los Angeles']}

#1. Creating a dataframe from a dictionary
df = pd.DataFrame(df_dict)

#2. Filling missing values
filled_df = df.fillna(10)

#3. Filling missing values using interpolation
in_filled_df = df.interpolate()

#4. Converting a dataframe to a numpy array
np_array = in_filled_df.to_numpy()
# Out:
# <ipython-input-54-9cd18e3e7735>:12: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   in_filled_df = df.interpolate()

# %%
# THIS BLOCK IS FOR GRADING
# DO NOT MODIFY THIS BLOCK

q2_answer = [str(df), str(filled_df), str(in_filled_df), str(np_array)]

# %% [markdown]
# ## Q3 - Visualization with Matplotlib

# %% [markdown]
# 1.   Create a plot using `data` as data.
# 2.   Create 9 plots using subplotting (nrows=3, ncols=3) and assign `data` to all of them.
# 3.   Answers of this question will not be used for grading. Being able to create the desired plot is just enough.

# %%
data = np.random.rand(100)
#1. Creating a plot

plt.plot(data)

# %%
data = np.random.rand(100)
#2. Creating several plots

fig, axs = plt.subplots(3,3)
axs[0,0].plot(data)
axs[0,1].plot(data)
axs[0,2].plot(data)
axs[1,0].plot(data)
axs[1,1].plot(data)
axs[1,2].plot(data)
axs[2,0].plot(data)
axs[2,1].plot(data)
axs[2,2].plot(data)

# Can be written as a loop (preferable)

# %%
# THIS BLOCK IS FOR GRADING
# DO NOT MODIFY THIS BLOCK

q3_answer = [True]

# %% [markdown]
# ## Q4 - TensorFlow Tensors

# %% [markdown]
# 1.   Create a non-modifiable tensor using `tensor_data` and assign it to variable `nm_tensor`.
# 2.   Create a modifiable tensor using `tensor_data` and assign it to variable `m_tensor`.
# 3.   Create a vector, matrix and a 3 dimentional tensor using `tf.zeros` and assign them to variables `vector_tensor`, `matrix_tensor`, `tensor_tensor`. (Shape is not important. Only number of dimentions will be considered when grading.)
# 4.   Assign data type, shape and number of dimentions of `nm_tensor` to variables `tensor_dtype`, `tensor_shape`, `tensor_dim`.
# 5.   Reshape nm_tensor and assign it to variable `reshaped_tensor`. New shape has to be `(1,3,3,3,3)`
# 6.   Squeeze `reshaped_tensor` and assign it to variable `squeezed_tensor`.
# 7.   Find sum of elements in `squeezed_tensor` and assign it to variable `sum`.
# 8.   Apply `sin()` function to `squeezed_tensor` element wise and assign it to variable `sin_tensor`.

# %%
tensor_data = np.array([[0.86358721, 0.585652  , 0.31340154],
      [0.02340486, 0.84437356, 0.32931956],
       [0.16082566, 0.63988754, 0.10348194],
       [0.56799696, 0.36081998, 0.02276922],
       [0.07835305, 0.67397078, 0.7755204 ],
       [0.30945604, 0.30026249, 0.89596164],
       [0.41114437, 0.04499957, 0.11950187],
       [0.65592142, 0.11830548, 0.66905521],
       [0.44629693, 0.2479512 , 0.76576996],
       [0.30692644, 0.97886461, 0.17921037],
       [0.29802619, 0.2966186 , 0.03338205],
       [0.18760116, 0.68463428, 0.48096892],
       [0.49649646, 0.79698369, 0.70635117],
       [0.37082139, 0.72704845, 0.77470509],
       [0.7215858 , 0.52580036, 0.29326205],
       [0.12916395, 0.02836171, 0.70177387],
       [0.66993763, 0.09401543, 0.31269853],
       [0.00416697, 0.18669267, 0.3014686 ],
       [0.02201653, 0.18128677, 0.86583204],
       [0.84570116, 0.94261877, 0.84196919],
       [0.90456938, 0.44175321, 0.88347067],
       [0.26241352, 0.03581617, 0.0498614 ],
       [0.36014425, 0.65311228, 0.26106746],
       [0.47676218, 0.19481174, 0.34415158],
       [0.43142057, 0.73398209, 0.47176634],
       [0.14559765, 0.85535239, 0.59402043],
       [0.83565536, 0.63699739, 0.2996138 ]])

# %%
#1. Creating a non-modifiable tensor
nm_tensor = tf.constant(tensor_data)

#2. Creating a modifiable tensor
m_tensor = tf.Variable(tensor_data)

#3. Creating a scalar, vector, matrix and a 3 dimentional tensor
vector_tensor = tf.zeros(3)
matrix_tensor = tf.zeros((3,3))
tensor_tensor = tf.zeros((3,3,3))

#4. Finding data type, shape and number of dimentions of a tensor
tensor_dtype = nm_tensor.dtype
tensor_shape = nm_tensor.shape
tensor_dim = nm_tensor.ndim

#5. Reshaping a tensor
reshaped_tensor = tf.reshape(nm_tensor, (1,3,3,3,3))

#6. Squeezing a tensor
squeezed_tensor = tf.squeeze(reshaped_tensor)

#7. Finding sum of elements in a tensor
sum = tf.reduce_sum(squeezed_tensor)

#8. Applying a function to a tensor
sin_tensor = tf.math.sin(squeezed_tensor)

# %%
# THIS BLOCK IS FOR GRADING
# DO NOT MODIFY THIS BLOCK

q4_answer = [str(tensor_dtype), str(tensor_shape), str(tensor_dim)]

# %% [markdown]
# ## Q5 - Best data type

# %% [markdown]
# 1. Change the data type of `int_tensor` to best data type that ever existed and assign it to variable named `perfect_tensor`.

# %%
int_tensor = tf.constant([1,2,3,4,5])

perfect_tensor = tf.cast(int_tensor, tf.float32)

# %%
# THIS BLOCK IS FOR GRADING
# DO NOT MODIFY THIS BLOCK

q5_answer = [str(perfect_tensor.dtype)]

# %% [markdown]
# ---
#
#
# # 02. Complete the Assignment
#
#
# ---

# %%
import pandas as pd

answers = [q1_answer, q2_answer, q3_answer, q4_answer, q5_answer]

print("I confirm that I did all the homework in this assignment by myself.\nI understand that if I am found to have cheated, I will forfeit my right to receive a certificate.")
confirmation = input("If you confirm the statement given above, type 'I confirm' to submit: ")
data = {
    "name": ["name", "datetime", "confirmation", "answers"],
    "data": [name, datetimenow, confirmation, answers]
}
answers_df = pd.DataFrame(data)
answers_df.set_index("name", inplace=True)
answers_df.to_csv("w2_submission.csv", index=True)
# Out:
# I confirm that I did all the homework in this assignment by myself.
# I understand that if I am found to have cheated, I will forfeit my right to receive a certificate.
# If you confirm the statement given above, type 'I confirm' to submit: I confirm
